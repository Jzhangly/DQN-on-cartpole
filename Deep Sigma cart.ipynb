# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from collections import deque
import random
import gym
import matplotlib
import matplotlib.pyplot as plt

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class DQN(nn.Module):

    def __init__(self, n_observations, n_actions,epsilon):
        super(DQN, self).__init__()
        self.nA = n_actions
        self.epsilon = epsilon
        self.layer1 = nn.Linear(n_observations, 128)
        self.layer2 = nn.Linear(128, 128)
        self.layer3 = nn.Linear(128, n_actions)
        
    def forward(self, x):
        x = F.relu(self.layer1(x))
        x = F.relu(self.layer2(x))
        return self.layer3(x)
    
    def action(self,state):        
        A = np.ones(self.nA, dtype=float) * (self.epsilon/self.nA)
        temp = self.forward(state)
        best_action = temp.max(1)[1].data[0].item()
        A[best_action] += 1.0 - self.epsilon
        return A

# %%
class replay_buffer(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = deque(maxlen=self.capacity)

    def storeX(self, state,action,GValue):
        state = state
        GValue = GValue
        action = action
        self.memory.append([state,action,GValue])
        
    def store(self, n_tuple,state,action):
        self.memory.append([state,action,n_tuple])
#         state = state
#         action = action
#         reward = reward
#         done = done
#         b_prob = b_prob
#         sigma = sigma
#         self.memory.append([state,action,reward,done,b_prob,sigma])

    def clear(self):
        self.memory.clear()
        
    def sample(self, batch_size):
        batch = random.sample(self.memory, batch_size)
        state,action, n_tuple= zip(* batch)
        return np.concatenate(state, 0),action, n_tuple

    def __len__(self):
        return len(self.memory)

# %%
def train(b_net,pi_net,buffer,optimizer,batch_size,count,soft_update,gamma):
    if len(buffer) < batch_size:
        return
    
    state,action, n_tuple = buffer.sample(batch_size)
    stateQ = torch.tensor(state, dtype=torch.float32, device=device)
    actionQ = torch.tensor(action, dtype=torch.long, device=device)
    storedG = []
    for tuples in n_tuple:
        state_t1 = tuples[0][0]
        action_t1 = tuples[0][1]
        q_t1 = pi_net.forward(state_t1).detach().squeeze(0)
        G = q_t1[action_t1]
        for state,action,reward,b_prob,sigma,done in tuples:
            if done:
                G = reward
            else:

                s_k = state
                a_k = action
                r_k = reward
                bProb_k = b_prob
                sigma = sigma

                pi_prob = pi_net.action(s_k)
                action = np.random.choice(actions,p=pi_prob)
                piProb_k = pi_prob[action]
                pho_k = piProb_k / bProb_k
                q_k = pi_net.forward(s_k).detach().squeeze(0)

                VBar = np.sum([(pi_prob[a]) * q_k[a] for a in range(action_dim)])
                G = r_k + gamma * ((sigma * pho_k) + ((1-sigma) * pi_prob[a_k])) * (G - q_k[a_k])+ gamma * VBar
        storedG.append(G)
    
    storedG = torch.tensor(storedG, dtype=torch.float32, device=device)
    
    q_values = b_net.forward(stateQ)
    q_value = q_values.gather(1, actionQ.unsqueeze(1)).squeeze(1)

    loss = (storedG - q_value).pow(2)
    print(loss)
    loss = loss.mean()
    print(loss)
    print("spacing")
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if count % soft_update == 0:
        pi_net.load_state_dict(b_net.state_dict())

# %%
def chooseSigma():
     return np.random.uniform(0, 1)

# %%
episode_durations = []
def plot_durations(show_result=False):
    plt.figure(1)
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    if show_result:
        plt.title('Result')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

# %%
gamma = 0.99
learning_rate = 1e-3
batch_size = 5
soft_update = 50
capacity = 10000
exploration = 10

episode = 600
n_step = 4
render = False
count = 0

buffer = replay_buffer(1000)

env = gym.make('CartPole-v1')
observation_dim = env.observation_space.shape[0]
action_dim = env.action_space.n
actions = list(range(0,env.action_space.n))

b_epsilon = 0.3
pi_epsilon = 0.1
b_net = DQN(observation_dim,action_dim,b_epsilon).to(device)
pi_net = DQN(observation_dim,action_dim,pi_epsilon).to(device)
b_net.load_state_dict(pi_net.state_dict())

optimizer = torch.optim.Adam(b_net.parameters(), lr=learning_rate)
for i in range(episode):
    
    T = np.inf
    t = 0
    tau = 0
    stored_actions = {}
    stored_states = {}
    stored_rewards = {}
    stored_bProb = {}
    stored_sigma={}
    stored_G = {}
    stored_done = {}
    
    state = env.reset()
    state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
    b_prob = b_net.action(state)
    pi_prob = pi_net.action(state)
    action = np.random.choice(actions,p=b_prob)
    b_actionProb = b_prob[action]

    stored_actions[0] = action
    stored_states[0] = state
    stored_bProb[0] = b_actionProb
    while True:
    
        count = count + 1
        
        if t < T:
            state, reward, done, info = env.step(action)
            state = torch.tensor(state, dtype=torch.float32, device=device).unsqueeze(0)
            stored_states[t+1] = state
            stored_rewards[t+1] = reward
            stored_done[t+1] = done
            if done:
                print(T)
                T = t + 1
                episode_durations.append(T)

                
            else:
                b_prob = b_net.action(state)

                
                action = np.random.choice(actions,p=b_prob)
                b_actionProb = b_prob[action]
                sigma = chooseSigma()
                
                stored_actions[t+1] = action
                stored_sigma[t+1] = sigma
                stored_bProb[t+1] = b_actionProb
                
        tau = t - n_step + 1
        if tau >= 0:
            
            n_tuple = []
            for k in range(min(t+1, T), tau, -1):
                
                s_k = stored_states[k]
                done_k = stored_done[k]
                r_k = stored_rewards[k]
                if k == T:
                    a_k = 0
                    bProb_k = 0
                    sigma_k = 0
                    
                else:
                    a_k = stored_actions[k]
                    bProb_k = stored_bProb[k]
                    sigma_k = stored_sigma[k]
                n_tuple.append([s_k,a_k,r_k,bProb_k,sigma_k,done_k])      
            s_tau= stored_states[tau]
            a_tau = stored_actions[tau]
            buffer.store(n_tuple,s_tau,a_tau)
        
        if i > exploration:
            train(b_net,pi_net,buffer,optimizer,batch_size,count,soft_update,gamma )
        if tau == (T-1):
            
            break
        else:
            t = t + 1

print('Complete')
plot_durations(show_result=True)

plt.savefig('results.png')
plt.show()
# Out:
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# tensor([  2.7005,  16.1784, 362.8735, 244.2822, 964.0118],
#        grad_fn=<PowBackward0>)
# tensor(318.0093, grad_fn=<MeanBackward0>)
# spacing
# tensor([16.2058,  1.9479,  3.5736,  2.4181,  0.2577], grad_fn=<PowBackward0>)
# tensor(4.8806, grad_fn=<MeanBackward0>)
# spacing
# tensor([16.1952, 18.1836, 24.0917, 14.4646, 15.8485], grad_fn=<PowBackward0>)
# tensor(17.7567, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 12.5340, 101.6134, 949.1942,  16.5151,  17.4255],
#        grad_fn=<PowBackward0>)
# tensor(219.4565, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 5.2263, 15.1749, 16.7740, 14.9756,  0.5697], grad_fn=<PowBackward0>)
# tensor(10.5441, grad_fn=<MeanBackward0>)
# spacing
# tensor([  3.1067, 346.1738,   8.7291,   1.4976,  11.9913],
#        grad_fn=<PowBackward0>)
# tensor(74.2997, grad_fn=<MeanBackward0>)
# spacing
# tensor([5.1685e-01, 1.3108e+01, 1.6342e+01, 4.7521e+01, 7.2564e+02],
#        grad_fn=<PowBackward0>)
# tensor(160.6255, grad_fn=<MeanBackward0>)
# spacing
# tensor([38.0466, 15.3188,  3.2784, 70.5418,  0.1159], grad_fn=<PowBackward0>)
# tensor(25.4603, grad_fn=<MeanBackward0>)
# spacing
# tensor([47.3331,  0.4225, 13.0883, 14.8580, 18.7698], grad_fn=<PowBackward0>)
# tensor(18.8943, grad_fn=<MeanBackward0>)
# spacing
# tensor([12.8955, 19.2295,  9.3825,  2.2804, 15.1510], grad_fn=<PowBackward0>)
# tensor(11.7878, grad_fn=<MeanBackward0>)
# spacing
# tensor([2.8698e-01, 9.8502e+00, 1.4742e+01, 5.4599e-01, 3.4131e+02],
#        grad_fn=<PowBackward0>)
# tensor(73.3475, grad_fn=<MeanBackward0>)
# spacing
# tensor([  0.2996,  11.4500, 112.4875,  14.2967,  13.6047],
#        grad_fn=<PowBackward0>)
# tensor(30.4277, grad_fn=<MeanBackward0>)
# spacing
# tensor([338.3473, 178.0005,  13.1784,  44.9531, 110.8913],
#        grad_fn=<PowBackward0>)
# tensor(137.0741, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 7.9880, 12.7708, 17.7099, 62.3856, 13.5358], grad_fn=<PowBackward0>)
# tensor(22.8780, grad_fn=<MeanBackward0>)
# spacing
# tensor([  1.3741,  14.5125,   8.2702,  12.0907, 123.0006],
#        grad_fn=<PowBackward0>)
# tensor(31.8496, grad_fn=<MeanBackward0>)
# spacing
# tensor([10.9749, 12.8695,  0.0275,  0.3233, 13.0531], grad_fn=<PowBackward0>)
# tensor(7.4497, grad_fn=<MeanBackward0>)
# spacing
# tensor([11.5897, 16.6136, 12.9564, 81.2598, 12.7407], grad_fn=<PowBackward0>)
# tensor(27.0320, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([ 4.3461,  9.1093,  4.5562, 11.7739, 12.6281], grad_fn=<PowBackward0>)
# tensor(8.4827, grad_fn=<MeanBackward0>)
# spacing
# tensor([  5.4426,   8.9203,   4.1934, 221.6448,   8.0731],
#        grad_fn=<PowBackward0>)
# tensor(49.6549, grad_fn=<MeanBackward0>)
# spacing
# tensor([14.6449, 14.1130, 34.2597,  4.0427,  2.6422], grad_fn=<PowBackward0>)
# tensor(13.9405, grad_fn=<MeanBackward0>)
# spacing
# tensor([36.8204,  0.3613, 14.0249, 11.6590, 15.4290], grad_fn=<PowBackward0>)
# tensor(15.6589, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 0.3696,  2.0413,  5.9624, 11.3608,  1.1477], grad_fn=<PowBackward0>)
# tensor(4.1764, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 6.4675,  0.0555,  6.1236,  4.4779, 13.8020], grad_fn=<PowBackward0>)
# tensor(6.1853, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 9.4458,  9.8584, 43.3188,  3.5000,  8.9541], grad_fn=<PowBackward0>)
# tensor(15.0154, grad_fn=<MeanBackward0>)
# spacing
# tensor([8.8452e-04, 1.0558e+01, 3.1412e+02, 9.0435e+00, 3.3324e+01],
#        grad_fn=<PowBackward0>)
# tensor(73.4099, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 7.0539,  2.1685,  6.4603,  6.7327, 71.8551], grad_fn=<PowBackward0>)
# tensor(18.8541, grad_fn=<MeanBackward0>)
# spacing
# tensor([6.8599, 8.1302, 4.9545, 0.1988, 1.4025], grad_fn=<PowBackward0>)
# tensor(4.3092, grad_fn=<MeanBackward0>)
# spacing
# tensor([34.6626,  0.1694,  1.0886,  7.7528,  0.2196], grad_fn=<PowBackward0>)
# tensor(8.7786, grad_fn=<MeanBackward0>)
# spacing
# tensor([4.3202e-01, 4.8830e+00, 3.2786e-01, 2.9789e+00, 7.0615e-04],
#        grad_fn=<PowBackward0>)
# tensor(1.7245, grad_fn=<MeanBackward0>)
# spacing
# tensor([10.7751, 11.6005,  0.7896,  5.0567, 63.3840], grad_fn=<PowBackward0>)
# tensor(18.3212, grad_fn=<MeanBackward0>)
# spacing
# tensor([7.2195e-02, 8.0422e+00, 1.0609e+02, 1.8169e+00, 2.9204e+01],
#        grad_fn=<PowBackward0>)
# tensor(29.0443, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 3.6312,  4.0846,  5.1140, 34.2994, 65.9565], grad_fn=<PowBackward0>)
# tensor(22.6172, grad_fn=<MeanBackward0>)
# spacing
# tensor([  0.6179,  23.7192,  15.3780,   4.4404, 216.8735],
#        grad_fn=<PowBackward0>)
# tensor(52.2058, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 29.7290,   1.0029, 198.6364,   4.1094,   0.2280],
#        grad_fn=<PowBackward0>)
# tensor(46.7411, grad_fn=<MeanBackward0>)
# spacing
# tensor([  6.3187, 210.2121,   2.9992,   1.8743,   9.3304],
#        grad_fn=<PowBackward0>)
# tensor(46.1469, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([ 1.0621, 12.0892,  2.5591,  0.9909,  6.8838], grad_fn=<PowBackward0>)
# tensor(4.7170, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 58.6539, 276.0601,   0.4061,   9.3360,   2.9512],
#        grad_fn=<PowBackward0>)
# tensor(69.4815, grad_fn=<MeanBackward0>)
# spacing
# tensor([19.3553,  3.9365,  3.6687,  3.1007,  5.8137], grad_fn=<PowBackward0>)
# tensor(7.1750, grad_fn=<MeanBackward0>)
# spacing
# tensor([2.0983e+01, 2.6811e+02, 5.3523e+00, 6.4100e+01, 1.9306e-01],
#        grad_fn=<PowBackward0>)
# tensor(71.7483, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 1.6387,  3.1389, 12.6364,  0.1571, 48.0086], grad_fn=<PowBackward0>)
# tensor(13.1159, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 0.2558,  0.3089,  7.4752,  0.5112, 29.2768], grad_fn=<PowBackward0>)
# tensor(7.5656, grad_fn=<MeanBackward0>)
# spacing
# tensor([  2.4129, 113.6430, 211.7809,   1.5690,   2.4353],
#        grad_fn=<PowBackward0>)
# tensor(66.3682, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 83.3359,   3.1792, 102.1450,   2.3657,  24.0224],
#        grad_fn=<PowBackward0>)
# tensor(43.0097, grad_fn=<MeanBackward0>)
# spacing
# tensor([5.6351e+00, 1.6030e-02, 2.8182e+02, 4.2272e+01, 1.7235e+01],
#        grad_fn=<PowBackward0>)
# tensor(69.3958, grad_fn=<MeanBackward0>)
# spacing
# tensor([3.9774e+00, 2.6129e+00, 4.3868e-07, 3.9682e+00, 1.2777e+01],
#        grad_fn=<PowBackward0>)
# tensor(4.6670, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 5.3097,  3.2815,  1.5635, 11.7083, 17.4157], grad_fn=<PowBackward0>)
# tensor(7.8558, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 0.0829, 13.2519,  1.4247, 10.9514,  1.1436], grad_fn=<PowBackward0>)
# tensor(5.3709, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([  7.0903, 579.5195,  32.0984,  52.7121,  41.0633],
#        grad_fn=<PowBackward0>)
# tensor(142.4967, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 47.6408,  32.1752,   8.7294,  21.5725, 100.6687],
#        grad_fn=<PowBackward0>)
# tensor(42.1573, grad_fn=<MeanBackward0>)
# spacing
# tensor([47.5772, 29.7120, 26.5760,  0.3116, 24.7728], grad_fn=<PowBackward0>)
# tensor(25.7899, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 25.0539,  38.5887, 560.9865,  13.5198,   9.9984],
#        grad_fn=<PowBackward0>)
# tensor(129.6295, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 29.4603,  14.1491,  52.1137, 621.2919,   9.8730],
#        grad_fn=<PowBackward0>)
# tensor(145.3776, grad_fn=<MeanBackward0>)
# spacing
# tensor([1.6765e+01, 2.1487e+02, 1.7944e+01, 1.4882e+02, 1.1393e-02],
#        grad_fn=<PowBackward0>)
# tensor(79.6817, grad_fn=<MeanBackward0>)
# spacing
# tensor([  0.7312,   8.2205, 374.6128,  20.0098,  19.3345],
#        grad_fn=<PowBackward0>)
# tensor(84.5818, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 22.6662, 293.7729,  14.8542,   6.1742,  35.2515],
#        grad_fn=<PowBackward0>)
# tensor(74.5438, grad_fn=<MeanBackward0>)
# spacing
# tensor([18.0247, 34.4768, 16.9956,  4.5716, 18.3748], grad_fn=<PowBackward0>)
# tensor(18.4887, grad_fn=<MeanBackward0>)
# spacing
# tensor([873.7292,  30.0581, 363.2337,  31.9519,  11.7676],
#        grad_fn=<PowBackward0>)
# tensor(262.1481, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 22.1174, 825.5894,  27.0340,  28.6888,  29.3831],
#        grad_fn=<PowBackward0>)
# tensor(186.5625, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([ 39.0371,  12.6676, 338.6943, 132.9936,  74.2866],
#        grad_fn=<PowBackward0>)
# tensor(119.5358, grad_fn=<MeanBackward0>)
# spacing
# tensor([248.9665,   7.6236,   6.7738,  37.3616,  37.2353],
#        grad_fn=<PowBackward0>)
# tensor(67.5922, grad_fn=<MeanBackward0>)
# spacing
# tensor([  6.5512, 338.9469,  12.0457,  12.6799, 119.3934],
#        grad_fn=<PowBackward0>)
# tensor(97.9234, grad_fn=<MeanBackward0>)
# spacing
# tensor([21.6223, 27.5240, 35.2020, 72.0964, 11.7900], grad_fn=<PowBackward0>)
# tensor(33.6470, grad_fn=<MeanBackward0>)
# spacing
# tensor([1.8387e-01, 9.2187e+01, 2.8764e+03, 1.0717e+02, 3.2560e+02],
#        grad_fn=<PowBackward0>)
# tensor(680.3030, grad_fn=<MeanBackward0>)
# spacing
# tensor([117.4804,   2.6530,   4.9361,   0.5979,   6.6104],
#        grad_fn=<PowBackward0>)
# tensor(26.4556, grad_fn=<MeanBackward0>)
# spacing
# tensor([113.6232,  28.2551,   4.4533, 430.9159,   3.7613],
#        grad_fn=<PowBackward0>)
# tensor(116.2018, grad_fn=<MeanBackward0>)
# spacing
# tensor([4.0149e+01, 1.7854e+01, 3.1380e-02, 1.9830e+02, 7.9363e+01],
#        grad_fn=<PowBackward0>)
# tensor(67.1389, grad_fn=<MeanBackward0>)
# spacing
# tensor([656.7851, 116.9909,   2.6423,   2.6362,   2.8035],
#        grad_fn=<PowBackward0>)
# tensor(156.3716, grad_fn=<MeanBackward0>)
# spacing
# tensor([  3.4539,  15.1685,   3.9466, 148.0540, 342.7986],
#        grad_fn=<PowBackward0>)
# tensor(102.6843, grad_fn=<MeanBackward0>)
# spacing
# tensor([  2.1634, 183.7885,   0.5781,  16.5005,  14.3755],
#        grad_fn=<PowBackward0>)
# tensor(43.4812, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([158.7585,   1.0193,   2.1856,   1.9441,   2.9111],
#        grad_fn=<PowBackward0>)
# tensor(33.3637, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 2.6282,  1.2751, 10.8410, 30.4160, 13.9951], grad_fn=<PowBackward0>)
# tensor(11.8311, grad_fn=<MeanBackward0>)
# spacing
# tensor([159.8011,   3.6611,  77.3692, 176.3230,  41.1297],
#        grad_fn=<PowBackward0>)
# tensor(91.6568, grad_fn=<MeanBackward0>)
# spacing
# tensor([139.3149,   9.5836,  45.7509,  17.6863,   4.7586],
#        grad_fn=<PowBackward0>)
# tensor(43.4189, grad_fn=<MeanBackward0>)
# spacing
# tensor([9.2301e-02, 8.3433e+01, 2.2811e-02, 5.1582e-01, 1.8773e-01],
#        grad_fn=<PowBackward0>)
# tensor(16.8503, grad_fn=<MeanBackward0>)
# spacing
# tensor([9.5921e+02, 2.3017e-02, 2.3344e+02, 7.3066e+01, 2.1261e+00],
#        grad_fn=<PowBackward0>)
# tensor(253.5730, grad_fn=<MeanBackward0>)
# spacing
# tensor([1.0140e+02, 5.6530e+01, 6.5574e+01, 1.5230e-01, 2.3084e+02],
#        grad_fn=<PowBackward0>)
# tensor(90.8988, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 94.5996,   0.7825, 301.0635,  60.4389,  53.9664],
#        grad_fn=<PowBackward0>)
# tensor(102.1702, grad_fn=<MeanBackward0>)
# spacing
# tensor([8.9878e-04, 1.8419e-03, 1.9737e-01, 1.6260e+02, 6.2946e+02],
#        grad_fn=<PowBackward0>)
# tensor(158.4527, grad_fn=<MeanBackward0>)
# spacing
# tensor([1.3564e+02, 7.4870e+02, 2.0566e-01, 9.1086e+01, 3.4582e+02],
#        grad_fn=<PowBackward0>)
# tensor(264.2909, grad_fn=<MeanBackward0>)
# spacing
# tensor([1.5146e+02, 1.5583e+02, 2.3054e+01, 1.0982e+02, 4.6558e-03],
#        grad_fn=<PowBackward0>)
# tensor(88.0317, grad_fn=<MeanBackward0>)
# spacing
# tensor([9.9696e+02, 4.3329e+01, 4.0254e-02, 8.6421e+01, 1.3231e+02],
#        grad_fn=<PowBackward0>)
# tensor(251.8133, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([2.5610e+01, 1.0473e+02, 1.9517e-01, 2.3394e-01, 6.4290e+02],
#        grad_fn=<PowBackward0>)
# tensor(154.7335, grad_fn=<MeanBackward0>)
# spacing
# tensor([4.5198e-03, 4.1439e-02, 1.7351e-02, 2.8864e+02, 1.4684e+00],
#        grad_fn=<PowBackward0>)
# tensor(58.0345, grad_fn=<MeanBackward0>)
# spacing
# tensor([9.1186e+01, 3.3239e+02, 7.6422e+00, 3.3709e-02, 1.5146e+02],
#        grad_fn=<PowBackward0>)
# tensor(116.5432, grad_fn=<MeanBackward0>)
# spacing
# tensor([9.0741e+01, 9.4334e+01, 1.1426e-01, 1.2596e+02, 2.5915e-01],
#        grad_fn=<PowBackward0>)
# tensor(62.2810, grad_fn=<MeanBackward0>)
# spacing
# tensor([7.4405e-02, 1.3137e+01, 1.6140e+00, 8.9051e-04, 1.2003e+02],
#        grad_fn=<PowBackward0>)
# tensor(26.9703, grad_fn=<MeanBackward0>)
# spacing
# tensor([7.8084e-02, 8.0475e-01, 2.7799e+00, 1.1957e+02, 5.4882e+00],
#        grad_fn=<PowBackward0>)
# tensor(25.7439, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 133.5432,   69.1588,  448.4403,   77.8976, 1479.6393],
#        grad_fn=<PowBackward0>)
# tensor(441.7358, grad_fn=<MeanBackward0>)
# spacing
# tensor([290.2706, 122.6525,   0.2989, 102.1163,  76.9903],
#        grad_fn=<PowBackward0>)
# tensor(118.4657, grad_fn=<MeanBackward0>)
# spacing
# tensor([2.2054e+01, 2.0521e+00, 7.9672e-02, 2.6521e+02, 1.2147e+02],
#        grad_fn=<PowBackward0>)
# tensor(82.1720, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 20.4521,  71.4639, 125.1574,  48.8372,  37.8620],
#        grad_fn=<PowBackward0>)
# tensor(60.7545, grad_fn=<MeanBackward0>)
# spacing
# tensor([55.8580, 48.1654, 81.0287, 87.1168,  5.8559], grad_fn=<PowBackward0>)
# tensor(55.6050, grad_fn=<MeanBackward0>)
# spacing
# tensor([7.6085e+01, 1.7520e+01, 5.7540e+01, 3.8730e+01, 7.0186e-02],
#        grad_fn=<PowBackward0>)
# tensor(37.9890, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 6.2158,  0.1425, 34.4139, 22.8924,  0.0467], grad_fn=<PowBackward0>)
# tensor(12.7422, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([7.1537e+01, 5.3439e-02, 9.4102e-02, 4.9900e+00, 4.0414e-05],
#        grad_fn=<PowBackward0>)
# tensor(15.3349, grad_fn=<MeanBackward0>)
# spacing
# tensor([4.1357e-03, 2.4072e+01, 1.3270e-02, 2.2409e-01, 9.5373e+00],
#        grad_fn=<PowBackward0>)
# tensor(6.7702, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 3.2111,  0.9589, 28.2729,  2.9234,  0.1607], grad_fn=<PowBackward0>)
# tensor(7.1054, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 14.4298,  11.1363,  36.6313, 712.6285,  29.6055],
#        grad_fn=<PowBackward0>)
# tensor(160.8863, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 50.5784,  14.8592, 173.3614, 282.7354, 313.6560],
#        grad_fn=<PowBackward0>)
# tensor(167.0381, grad_fn=<MeanBackward0>)
# spacing
# tensor([25.6938, 15.4348,  7.4984, 15.2948, 14.7993], grad_fn=<PowBackward0>)
# tensor(15.7442, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 15.8052,  16.3475,  17.8736, 294.8047,  31.9150],
#        grad_fn=<PowBackward0>)
# tensor(75.3492, grad_fn=<MeanBackward0>)
# spacing
# tensor([  4.3011, 314.9107, 298.0780, 142.6806,  20.6793],
#        grad_fn=<PowBackward0>)
# tensor(156.1299, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 7.7290, 30.2754, 57.7561, 13.9916, 40.6160], grad_fn=<PowBackward0>)
# tensor(30.0736, grad_fn=<MeanBackward0>)
# spacing
# tensor([24.3563, 20.2330, 39.1345, 14.2832, 31.2172], grad_fn=<PowBackward0>)
# tensor(25.8449, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 25.4741,  14.7271,  29.6121, 255.2208,  22.5627],
#        grad_fn=<PowBackward0>)
# tensor(69.5194, grad_fn=<MeanBackward0>)
# spacing
# tensor([  24.4997,   22.0496, 1011.6106,  101.1472,   32.4350],
#        grad_fn=<PowBackward0>)
# tensor(238.3484, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([ 12.9311, 621.3041,  20.7903,  26.7942,  16.7408],
#        grad_fn=<PowBackward0>)
# tensor(139.7121, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 20.4646,  29.6398,  14.9799, 472.1970, 105.6787],
#        grad_fn=<PowBackward0>)
# tensor(128.5920, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 23.1139, 163.5709, 106.2391,  24.9223,  16.6340],
#        grad_fn=<PowBackward0>)
# tensor(66.8960, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 40.2884,  11.6126, 157.9862,   1.5970, 144.9587],
#        grad_fn=<PowBackward0>)
# tensor(71.2886, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 10.7146, 471.9402,  34.8511, 142.7224,  32.8309],
#        grad_fn=<PowBackward0>)
# tensor(138.6119, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 31.6095,  14.5977,  42.6194, 716.2963,  22.4993],
#        grad_fn=<PowBackward0>)
# tensor(165.5244, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 7.4317, 23.8548, 18.4626,  8.2003, 15.4610], grad_fn=<PowBackward0>)
# tensor(14.6821, grad_fn=<MeanBackward0>)
# spacing
# tensor([1.3995e+03, 8.1638e+00, 2.0092e+01, 4.0446e+01, 4.3950e-02],
#        grad_fn=<PowBackward0>)
# tensor(293.6509, grad_fn=<MeanBackward0>)
# spacing
# tensor([   7.0210,   24.5874,   14.3174, 3017.5103,  453.0315],
#        grad_fn=<PowBackward0>)
# tensor(703.2935, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 43.3043, 155.5359,   4.8727,   8.5575, 219.6242],
#        grad_fn=<PowBackward0>)
# tensor(86.3789, grad_fn=<MeanBackward0>)
# spacing
# tensor([  48.9777,   30.3870,   30.0173, 1191.4745,    3.8952],
#        grad_fn=<PowBackward0>)
# tensor(260.9503, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 13.6800, 303.4494,   4.3692,   4.6823,   3.6422],
#        grad_fn=<PowBackward0>)
# tensor(65.9646, grad_fn=<MeanBackward0>)
# spacing
# tensor([  3.3217,   2.2329,  14.2645, 656.1699,   9.2285],
#        grad_fn=<PowBackward0>)
# tensor(137.0435, grad_fn=<MeanBackward0>)
# spacing
# tensor([  5.6114,  10.9517,  42.5787, 120.8178,   4.4813],
#        grad_fn=<PowBackward0>)
# tensor(36.8882, grad_fn=<MeanBackward0>)
# spacing
# tensor([254.9888,   1.7179, 201.5821,   2.4846, 228.2052],
#        grad_fn=<PowBackward0>)
# tensor(137.7957, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([  2.3808,  21.1052,  38.2466, 159.5820,  35.3403],
#        grad_fn=<PowBackward0>)
# tensor(51.3310, grad_fn=<MeanBackward0>)
# spacing
# tensor([6.6028e+01, 5.2686e+01, 7.6994e-02, 2.1544e+02, 2.8385e+00],
#        grad_fn=<PowBackward0>)
# tensor(67.4132, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 59.6993,  10.9855, 126.2144, 120.4703,  12.6329],
#        grad_fn=<PowBackward0>)
# tensor(66.0005, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 8.4660, 54.9580, 49.8271,  4.1908, 40.3207], grad_fn=<PowBackward0>)
# tensor(31.5525, grad_fn=<MeanBackward0>)
# spacing
# tensor([131.2609,  46.8039,   1.0279,   7.2706,  95.7545],
#        grad_fn=<PowBackward0>)
# tensor(56.4236, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 7.0305,  0.1625, 81.8707, 71.2079,  0.6093], grad_fn=<PowBackward0>)
# tensor(32.1762, grad_fn=<MeanBackward0>)
# spacing
# tensor([  0.5286,   2.9534,  87.6107,  28.9664, 236.3484],
#        grad_fn=<PowBackward0>)
# tensor(71.2815, grad_fn=<MeanBackward0>)
# spacing
# tensor([7.6311e+00, 6.3092e+01, 7.1292e+01, 2.7744e+03, 1.5662e+00],
#        grad_fn=<PowBackward0>)
# tensor(583.5983, grad_fn=<MeanBackward0>)
# spacing
# tensor([ 1.2309, 77.2012,  0.2146,  2.9742, 64.5893], grad_fn=<PowBackward0>)
# tensor(29.2420, grad_fn=<MeanBackward0>)
# spacing
# tensor([8.2141e+01, 8.5742e+01, 2.0413e-03, 7.7662e+01, 2.1675e+00],
#        grad_fn=<PowBackward0>)
# tensor(49.5429, grad_fn=<MeanBackward0>)
# spacing
# tensor([1.4458e-02, 1.9675e+00, 4.9388e+01, 7.0054e+01, 6.3158e+01],
#        grad_fn=<PowBackward0>)
# tensor(36.9165, grad_fn=<MeanBackward0>)
# spacing
# inf
# tensor([  0.2063,   1.3091,   0.7659,  58.1733, 180.9317],
#        grad_fn=<PowBackward0>)
# tensor(48.2772, grad_fn=<MeanBackward0>)
# spacing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4656\1173646289.py in <module>
#     100
#     101         if i > exploration:
# --> 102             train(b_net,pi_net,buffer,optimizer,batch_size,count,soft_update,gamma )
#     103         if tau == (T-1):
#     104
#
# ~\AppData\Local\Temp\ipykernel_4656\915537980.py in train(b_net, pi_net, buffer, optimizer, batch_size, count, soft_update, gamma)
#      23                 sigma = sigma
#      24
# ---> 25                 pi_prob = pi_net.action(s_k)
#      26                 action = np.random.choice(actions,p=pi_prob)
#      27                 piProb_k = pi_prob[action]
#
# ~\AppData\Local\Temp\ipykernel_4656\314839376.py in action(self, state)
#      16     def action(self,state):
#      17         A = np.ones(self.nA, dtype=float) * (self.epsilon/self.nA)
# ---> 18         temp = self.forward(state)
#      19         best_action = temp.max(1)[1].data[0].item()
#      20         A[best_action] += 1.0 - self.epsilon
#
# ~\AppData\Local\Temp\ipykernel_4656\314839376.py in forward(self, x)
#      11     def forward(self, x):
#      12         x = F.relu(self.layer1(x))
# ---> 13         x = F.relu(self.layer2(x))
#      14         return self.layer3(x)
#      15
#
# ~\anaconda3\lib\site-packages\torch\nn\functional.py in relu(input, inplace)
#    1455         result = torch.relu_(input)
#    1456     else:
# -> 1457         result = torch.relu(input)
#    1458     return result
#    1459
#
# KeyboardInterrupt:
